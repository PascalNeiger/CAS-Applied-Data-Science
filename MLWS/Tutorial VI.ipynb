# %% [markdown]
# # Tutorial VI: Recurrent Neural Networks

# %% [markdown]
# <p>
# Bern Winter School on Machine Learning, 28.01-01.02 2019<br>
# Mykhailo Vladymyrov
# </p>
#
# This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# In this session we will see what RNN is. We will use it to predict/generate text sequence, but same approach can be applied to any sequential data.
#
#
# (Largely adopted from `https://github.com/roatienza/Deep-Learning-Experiments`)

# %% [markdown]
# So far we looked at the data available altogether. In many cases the data is sequential (weather, speach, sensor signals etc).
# RNNs are specifically designed for such tasks.
#
# ![rnn.png](https://scits-training.unibe.ch/data/figures/rnn.png)

# %% [markdown]
# ## download libraries

# %%
! wget http://scits-training.unibe.ch/data/tut_files/t6.tgz
! tar -xvzf t6.tgz
# Out:
# --2019-02-01 09:20:53--  http://scits-training.unibe.ch/data/tut_files/t6.tgz
# Resolving scits-training.unibe.ch (scits-training.unibe.ch)... 130.92.251.56
# Connecting to scits-training.unibe.ch (scits-training.unibe.ch)|130.92.251.56|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6896 (6.7K) [application/octet-stream]
# Saving to: 't6.tgz'
#
# t6.tgz              100%[===================>]   6.73K  --.-KB/s    in 0s
#
# 2019-02-01 09:20:53 (305 MB/s) - 't6.tgz' saved [6896/6896]
#
# RNN/
# RNN/belling_the_cat.txt
# RNN/rnn.txt
# utils/
# utils/gr_disp.py
# utils/inception.py
# utils/__init__.py
# tar: A lone zero block at 42

# %% [markdown]
# ## 1. Load necessary libraries

# %%
import sys

import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipyd
import tensorflow as tf
import collections
import time

# We'll tell matplotlib to inline any drawn figures like so:
# %matplotlib inline
plt.style.use('ggplot')
from utils import gr_disp

from IPython.core.display import HTML
HTML("""<style> .rendered_html code { 
    padding: 2px 5px;
    color: #0000aa;
    background-color: #cccccc;
} </style>""")
# Out:
# <style> .rendered_html code {
#     padding: 2px 5px;
#     color: #0000aa;
#     background-color: #cccccc;
# } </style>

# %% [markdown]
# ## 2. Load the text data

# %%
def read_data(fname):
    with open(fname) as f:
        content = f.readlines()
    content = [x.strip() for x in content]
    content = [word for i in range(len(content)) for word in content[i].split()]
    content = np.array(content)
    return content

# %%
training_file = 'RNN/rnn.txt'

# %%
training_data = read_data(training_file)

# %%
print(training_data[:300])
# Out:
# ['recurrent' 'neural' 'networks' ',' 'or' 'rnns' '(' 'rumelhart' 'et' 'al'
#  '.' ',' '1986a' ')' ',' 'are' 'a' 'family' 'of' 'neural' 'networks' 'for'
#  'processing' 'sequential' 'data' '.' 'much' 'as' 'a' 'convolutional'
#  'network' 'is' 'a' 'neural' 'network' 'that' 'is' 'specialized' 'for'
#  'processing' 'a' 'grid' 'of' 'values' 'such' 'as' 'an' 'image' ',' 'a'
#  'recurrent' 'neural' 'network' 'is' 'a' 'neural' 'network' 'that' 'is'
#  'specialized' 'for' 'processing' 'a' 'sequence' 'of' 'values' 'x' '(' '1'
#  ')' ',' '.' '.' '.' ',' 'x' '(' 'tau' ')' '.' 'just' 'as' 'convolutional'
#  'networks' 'can' 'readily' 'scale' 'to' 'images' 'with' 'large' 'width'
#  'and' 'height' ',' 'and' 'some' 'convolutional' 'networks' 'can'
#  'process' 'images' 'of' 'variable' 'size' ',' 'recurrent' 'networks'
#  'can' 'scale' 'to' 'much' 'longer' 'sequences' 'than' 'would' 'be'
#  'practical' 'for' 'networks' 'without' 'sequence' '-' 'based'
#  'specialization' '.' 'most' 'recurrent' 'networks' 'can' 'also' 'process'
#  'sequences' 'of' 'variable' 'length' '.' 'to' 'go' 'from' 'multilayer'
#  'networks' 'to' 'recurrent' 'networks' ',' 'we' 'need' 'to' 'take'
#  'advantage' 'of' 'one' 'of' 'the' 'early' 'ideas' 'found' 'in' 'machine'
#  'learning' 'and' 'statistical' 'models' 'of' 'the1980s' ':' 'sharing'
#  'parameters' 'across' 'different' 'parts' 'of' 'a' 'model' '.'
#  'parameter' 'sharing' 'makes' 'it' 'possible' 'to' 'extend' 'and' 'apply'
#  'the' 'model' 'to' 'examples' 'of' 'different' 'forms' '(' 'different'
#  'lengths' ',' 'here' ')' 'and' 'generalize' 'across' 'them' '.' 'if' 'we'
#  'had' 'separate' 'parameters' 'for' 'each' 'value' 'of' 'the' 'time'
#  'index' ',' 'we' 'could' 'not' 'generalize' 'to' 'sequence' 'lengths'
#  'not' 'seen' 'during' 'training' ',' 'nor' 'share' 'statistical'
#  'strength' 'across' 'different' 'sequence' 'lengths' 'and' 'across'
#  'different' 'positions' 'in' 'time' '.' 'such' 'sharing' 'is'
#  'particularly' 'important' 'when' 'a' 'specific' 'piece' 'of'
#  'information' 'can' 'occur' 'at' 'multiple' 'positions' 'within' 'the'
#  'sequence' '.' 'for' 'example' ',' 'consider' 'the' 'two' 'sentences' '"'
#  'i' 'went' 'to' 'nepal' 'in' '2009' '"' 'and' '"' 'in' '2009' ',' 'i'
#  'went' 'to' 'nepal' '.' '"' 'if' 'we' 'ask' 'a' 'machine' 'learning'
#  'model' 'to' 'read' 'each' 'sentence']

# %% [markdown]
# ## 3. Build dataset
# We will assign an id to each word, and make dictionaries word->id and id->word.
# The most frequently repeating words have lowest id

# %%
def build_dataset(words):
    count = collections.Counter(words).most_common()
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reverse_dictionary

# %%
dictionary, reverse_dictionary = build_dataset(training_data)
vocab_size = len(dictionary)

# %%
print(dictionary)
# Out:
# {'feature': 242, 'examples': 144, 'related': 243, 'models': 371, 'exposition': 482, 'grid': 245, 'practice': 246, 'to': 7, 'than': 58, 'major': 248, 'position': 145, 'form': 249, 'represented': 146, 'can': 26, 'learns': 251, '2012': 252, 'general': 147, 'has': 82, 'nepal': 103, 'recover': 253, 'specified': 148, 'rewrite': 254, 'what': 317, 'mapping': 256, 'point': 257, 'any': 149, 'take': 376, 'applied': 105, 'manifests': 258, 'diagram': 199, 'learned': 260, 'classical': 261, 'passage': 262, 'out': 263, 'figure': 71, 'represent': 107, 'repeated': 150, 'operation': 151, 'image': 264, 'regardless': 250, 'involving': 194, 'computations': 265, '1989': 266, 'possible': 79, 'advantage': 267, 'hidden': 152, 'recurrent': 18, 'refers': 173, 'unfolding': 68, 'simplify': 270, 'requires': 272, 'fully': 273, 'readily': 274, 'state': 27, 'in': 8, 'selectively': 275, 'connected': 276, 'like': 277, 'typically': 108, 'share': 109, 'idea': 80, 'all': 69, 'specialization': 278, 'same': 55, 'extract': 280, 'learn': 110, 'shared': 281, 'based': 282, 'spatial': 283, 'go': 153, 'backward': 284, 'separate': 81, 'vector': 285, 'most': 154, 'reader': 286, 'describe': 287, 'members': 155, 'other': 156, 'ask': 157, 'height': 289, 'involved': 290, 'variable': 53, 'feedforward': 158, 'criterion': 292, 'g': 70, '2009': 111, 'early': 293, 'results': 159, 'the1980s': 294, 'size': 112, 'words': 295, ';': 33, 'draw': 160, 'formalize': 296, 'states': 297, 'square': 298, 'another': 161, 'include': 299, 'values': 113, 'previous': 114, 'weights': 381, 'yielded': 421, 'ways': 102, 'enables': 304, 'lossy': 162, 'modeling': 305, 'inputs': 163, 'even': 306, 'an': 51, 'every': 164, 'usually': 307, 'maps': 165, 'storing': 166, 'data': 115, 'considered': 167, 'them': 308, 'waibel': 309, 'which': 168, 'similar': 310, 'temporal': 311, 'events': 341, 'operating': 312, 'see': 313, 'width': 314, 'went': 116, 'this': 34, 'arbitrary': 315, 'does': 316, 'loss': 255, 'factorize': 318, 'information': 54, 'forms': 320, 'introduction': 321, 'kernel': 322, 'function': 47, 'applying': 169, ':': 83, 'approach': 462, 'parts': 170, 'rich': 324, 'chain': 326, 'delay': 171, 'required': 327, 'length': 48, 'transition': 172, 'generalization': 328, 'sentences': 239, 'convolutional': 84, 'convolution': 85, 'external': 329, 'd': 350, 'autoencoder': 331, 'repetitive': 332, 'world': 333, 'processing': 138, 'own': 335, 'notation': 336, 'we': 19, 'sequential': 337, 'extends': 338, 'about': 268, 'time': 11, 'used': 339, 'signal': 340, 'language': 227, 'through': 342, 'per': 343, 'predicting': 344, 'up': 174, 'past': 74, 'specialized': 175, 'found': 347, 'multilayer': 348, 'strength': 349, 'during': 259, 'number': 176, 'large': 330, 'steps': 59, 'training': 86, 'consider': 119, 'rest': 351, 'sometimes': 352, '1990': 449, 'operates': 177, 'explain': 353, 'vectors': 354, 'expression': 178, 'sharing': 52, 'whose': 355, 'system': 120, 'make': 187, 'second': 357, 'ranging': 319, 'repeatedly': 359, 'real': 179, 'traditional': 188, 'et': 121, '-': 23, '+': 394, 'as': 16, '3': 87, 'and': 24, 'also': 180, 'define': 181, 'each': 28, 'section': 182, 'unfolded': 60, 'interaction': 361, 'please': 362, 'units': 183, 'so': 478, 'multiple': 363, 'future': 123, 'allows': 132, '1': 12, 'relevant': 184, 'rumelhart': 365, 'specific': 378, 'connections': 467, 'the': 0, 'set': 185, 's': 46, 'view': 366, 'allow': 186, 'present': 356, 'moreover': 367, 'networks': 22, '(': 4, 'or': 96, 'circuit': 124, 'have': 140, 'observed': 369, 'thus': 370, 'structure': 89, 'without': 238, 'rather': 213, 'containing': 372, 'essentially': 373, 'al': 125, 'construct': 374, 'statistical': 126, 'biological': 375, 'single': 104, 'shallow': 377, 'rules': 358, 'separately': 379, 'across': 41, 'parameter': 127, 'not': 61, 'x': 13, 'operate': 380, 'minibatches': 300, 'acyclic': 382, 'implementation': 303, 'learning': 128, 'suppose': 383, 'particularly': 416, 'into': 189, 'parameters': 42, 'be': 29, 'deep': 190, 'only': 191, 'shares': 438, 'scale':  ...

# %% [markdown]
# ## 4. Build model

# %%
# Parameters
learning_rate = 0.001
training_iters = 250000
display_step = 1000
n_input = 7

# number of units in RNN cell
n_hidden = [1024, 512]

def RNN(x, n_vocab, n_hid):
    x = tf.unstack(x, n_input, 1)

    basic_cells = [tf.nn.rnn_cell.LSTMCell(n) for n in n_hid]
    rnn_cell = tf.nn.rnn_cell.MultiRNNCell(basic_cells)
    
    # generate prediction
    outputs, states = tf.nn.static_rnn(rnn_cell, x, dtype=tf.float32)

    # there are n_input outputs but
    # we only want the last output
    last_output = outputs[-1]
    
    w = tf.Variable(tf.random_normal([n_hid[-1], n_vocab]))
    b = tf.Variable(tf.random_normal([n_vocab]))
    y = tf.matmul(last_output, w) + b
    return y

                    
g = tf.Graph()
with g.as_default():
    # tf Graph input
    x = tf.placeholder("float", [None, n_input, 1])
    y = tf.placeholder("float", [None, vocab_size])
    
    pred = RNN(x, vocab_size, n_hidden)

    # Loss and optimizer
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=pred, labels=y))
    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

    # Model evaluation
    correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
gr_disp.show(g.as_graph_def())
# Out:
#             <iframe seamless style="width:800px;height:620px;border:0" srcdoc="
#             <script>
#               function load() {
#                 document.getElementById(&quot;graph0.1398394044284238&quot;).pbtxt = 'node {\n  name: &quot;Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 5\n        }\n        dim {\n          size: 1\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Placeholder/1&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 493\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;unstack&quot;\n  op: &quot;Unpack&quot;\n  input: &quot;Placeholder&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;axis&quot;\n    value {\n      i: 1\n    }\n  }\n  attr {\n    key: &quot;num&quot;\n    value {\n      i: 5\n    }\n  }\n}\nnode {\n  name: &quot;rnn/Shape&quot;\n  op: &quot;Shape&quot;\n  input: &quot;unstack&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;out_type&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;rnn/strided/slice/stack&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;rnn/strided/slice/stack_1&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;rnn/strided/slice/stack_2&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;rnn/strided/slice&quot;\n  op: &quot;StridedSlice&quot;\n  input: &quot;rnn/Shape&quot;\n  input: &quot;rnn/strided/slice/stack&quot;\n  input: &quot;rnn/strided/slice/stack_1&quot;\n  input: &quot;rnn/strided/slice/stack_2&quot;\n  attr {\n    key: &quot;Index&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;begin_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;ellipsis_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;end_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;new_axis_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;shrink_axis_mask&quot;\n    value {\n      i: 1\n    }\n  }\n}\nnode {\n  name: &quot;rnn/MultiRNNCellZeroState/LSTMCellZeroState/ExpandDims/dim&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n        }\n        int_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;rnn/MultiRNNCellZeroState/LSTMCellZeroState/ExpandDims&quot;\n  op: &quot;ExpandDims&quot;\n  input: &quot;rnn/strided/slice&quot;\n  input: &quot;rnn/MultiRNNCellZeroState/LSTMCellZeroState/ExpandDims/dim&quot;\n ...

# %% [markdown]
# ## 5. Run!

# %%
with tf.Session(graph=g) as session:
    session.run(tf.global_variables_initializer())
    step = 0
    offset = np.random.randint(0,n_input+1)
    end_offset = n_input + 1
    acc_total = 0
    loss_total = 0

    start_time = time.time()
    while step < training_iters:
        # Generate a minibatch. Add some randomness on selection process.
        if offset > (len(training_data)-end_offset):
            offset = np.random.randint(0, n_input+1)

        symbols_in_keys = [ [dictionary[ str(training_data[i])]] for i in range(offset, offset+n_input) ]
        symbols_in_keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])

        symbols_out_onehot = np.zeros([vocab_size], dtype=float)
        symbols_out_onehot[dictionary[str(training_data[offset+n_input])]] = 1.0
        symbols_out_onehot = np.reshape(symbols_out_onehot,[1,-1])

        _, acc, loss, onehot_pred = session.run([optimizer, accuracy, cost, pred], \
                                                feed_dict={x: symbols_in_keys, y: symbols_out_onehot})
        loss_total += loss
        acc_total += acc
        if (step+1) % display_step == 0:
            print("Iter= " + str(step+1) + ", Average Loss= " + \
                  "{:.6f}".format(loss_total/display_step) + ", Average Accuracy= " + \
                  "{:.2f}%".format(100*acc_total/display_step))
            acc_total = 0
            loss_total = 0
            symbols_in = [training_data[i] for i in range(offset, offset + n_input)]
            symbols_out = training_data[offset + n_input]
            symbols_out_pred = reverse_dictionary[int(tf.argmax(onehot_pred, 1).eval())]
            print("%s - [%s] vs [%s]" % (symbols_in,symbols_out,symbols_out_pred))
        step += 1
        offset += (n_input+1)
    print("Optimization Finished!")
    print("Elapsed time: ", time.time() - start_time)

    
    for itr in range(100):
        prompt = "%s words: " % n_input
        sentence = input(prompt)
        sentence = sentence.strip()
        words = sentence.split(' ')
        if len(words) != n_input:
            continue
        try:
            symbols_in_keys = [dictionary[str(words[i])] for i in range(len(words))]
            for i in range(128):
                keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])
                onehot_pred = session.run(pred, feed_dict={x: keys})
                onehot_pred_index = int(tf.argmax(onehot_pred, 1).eval())
                sentence = "%s %s" % (sentence,reverse_dictionary[onehot_pred_index])
                symbols_in_keys = symbols_in_keys[1:]
                symbols_in_keys.append(onehot_pred_index)
            print(sentence)
        except:
            print("Word not in dictionary")
# Out:
# Iter= 1000, Average Loss= 7.881673, Average Accuracy= 2.30%
# ['state', 'at', 'time', 't', 'to', 'the', 'state'] - [at] vs [the]
# Iter= 2000, Average Loss= 5.757039, Average Accuracy= 4.20%
# ['a', 'recurrent', 'neural', 'network', '.', 'many', 'recurrent'] - [neural] vs [)]
# Iter= 3000, Average Loss= 5.622638, Average Accuracy= 5.20%
# ['recurrent', 'neural', 'networks', '.', 'we', 'then', 'describe'] - [many] vs [of]
# Iter= 4000, Average Loss= 5.437735, Average Accuracy= 4.80%
# ['sixth', 'word', 'or', 'in', 'the', 'second', 'word'] - [of] vs [the]
# Iter= 5000, Average Loss= 5.433819, Average Accuracy= 4.90%
# ['state', 'to', 'another', 'state', ',', 'rather', 'than'] - [specified] vs [t]
# Iter= 6000, Average Loss= 5.479347, Average Accuracy= 4.80%
# ['chapter', '14', ')', '.', 'equation', '10', '.'] - [5] vs [the]
# Iter= 7000, Average Loss= 5.444962, Average Accuracy= 4.80%
# ['acyclic', 'computational', 'graph', '.', 'the', 'unfolded', 'computational'] - [graph] vs [)]
# Iter= 8000, Average Loss= 5.495313, Average Accuracy= 6.00%
# ['not', 'literally', 'refer', 'to', 'the', 'passage', 'of'] - [time] vs [the]
# Iter= 9000, Average Loss= 5.473743, Average Accuracy= 7.10%
# ['each', 'value', 'of', 'the', 'time', 'index', ','] - [we] vs [the]
# Iter= 10000, Average Loss= 5.483240, Average Accuracy= 6.40%
# ['t', ')', ';', 'theta', ')', '.', '('] - [10] vs [(]
# Iter= 11000, Average Loss= 5.542959, Average Accuracy= 5.00%
# ['(', 't', ')', '.', 'depending', 'on', 'the'] - [training] vs [t]
# Iter= 12000, Average Loss= 5.606437, Average Accuracy= 5.00%
# ['graph', 'can', 'be', 'unfolded', 'by', 'applying', 'the'] - [definition] vs [the]
# Iter= 13000, Average Loss= 5.639647, Average Accuracy= 5.70%
# ['output', 'is', 'produced', 'using', 'the', 'same', 'update'] - [rule] vs [the]
# Iter= 14000, Average Loss= 5.740581, Average Accuracy= 6.50%
# [',', 'recurrent', 'networks', 'can', 'scale', 'to', 'much'] - [longer] vs [a]
# Iter= 15000, Average Loss= 5.915339, Average Accuracy= 6.10%
# ['repeated', 'pieces', ',', 'as', 'in', 'the', 'right'] - [side] vs [of]
# Iter= 16000, Average Loss= 5.838674, Average Accuracy= 5.50%
# ['a', 'task', 'that', 'requires', 'predicting', 'the', 'future'] - [from] vs [.]
# Iter= 17000, Average Loss= 5.883933, Average Accuracy= 5.10%
# ['a', 'chain', 'of', 'events', '.', 'unfolding', 'this'] - [graph] vs [to]
# Iter= 18000, Average Loss= 6.127358, Average Accuracy= 5.60%
# [';', 'waibel', 'et', 'al', '.', ',', '1989'] - [;] vs [a]
# Iter= 19000, Average Loss= 5.569961, Average Accuracy= 7.10%
# ['neural', 'networks', ',', 'or', 'rnns', '(', 'rumelhart'] - [et] vs [,]
# Iter= 20000, Average Loss= 6.180417, Average Accuracy= 6.20%
# ['time', 't', 'to', 'the', 'state', 'at', 'time'] - [t] vs [a]
# Iter= 21000, Average Loss= 6.292999, Average Accuracy= 5.50%
# ['.', 'many', 'recurrent', 'neural', 'networks', 'use', 'equation'] - [10] vs [network]
# Iter= 22000, Average Loss= 6.401842, Average Accuracy= 6.40%
# ['neural', 'networks', '.', 'we', 'then', 'describe', 'many'] - [different] vs [.]
# Iter= 23000, Average Loss= 6.195300, Average Accuracy= 6.50%
# ['2009', 'as', 'the', 'relevant', 'piece', 'of', 'information'] - [,] vs [model]
# Iter= 24000, Average Loss= 6.070075, Average Accuracy= 7.70%
# ['specified', 'in', 'terms', 'of', 'transition', 'from', 'one'] - [state] vs [is]
# Iter= 25000, Average Loss= 6.257211, Average Accuracy= 5.70%
# ['in', 'autoencoder', 'frameworks', '(', 'chapter', '14', ')'] - [.] vs [t]
# Iter= 26000, Average Loss= 6.234751, Average Accuracy= 7.40%
# ['equation', '10', '.', '3', 'is', 'illustrated', 'in'] - [figure] vs [operating]
# Iter= 27000, Average Loss= 6.154187, Average Accuracy= 9.70%
# ['to', 'the', 'passage', 'of', 'time', 'in', 'the'] - [real] vs [1]
# Iter= 28000, Average Loss= 6.024800, Average Accuracy= 7.30%
# ['not', 'seen', 'during', 'training', ',', 'nor', 'share'] - [statistical] vs [,]
# Iter= 29000, Average Loss= 5.957688, Average Accuracy= 9.20%
# [')', 'takes', 'the', 'whole', 'past', 'sequence', '('] - [x] vs [the]
# Iter= 30000, Average Loss= 6.220081, Average Accuracy= 6.50%
# ['training', 'criterion', ',', 'this', 'summary', 'might', 'selectively'] - [keep] vs [the]
# Iter= 31000, Average Loss= 6.038922, Average Accuracy= 7.40%
# ['graph', 'can', 'be', 'unfolded', 'by', 'applying', 'the'] - [definition] vs [state]
# Iter= 32000, Average Loss= 6.046522, Average Accuracy= 8.50%
# ['applied', 'to', 'the', 'previous', 'outputs', '.', 'this'] - [recurrent] vs [in]
# Iter= 33000, Average Loss= 5.984073, Average Accuracy= 10.90%
# [',', 'recurrent', 'networks', 'can', 'scale', 'to', 'much'] - [longer] vs [a]
# Iter= 34000, Average Loss= 5.844103, Average Accuracy= 10.20%
# [',', 'to', 'a', 'computational', 'graph', 'with', 'repeated'] - [pieces] vs [for]
# Iter= 35000, Average Loss= 6.018968, Average Accuracy= 9.60%
# ['.', 'when', 'the', 'recurrent', 'network', 'is', 'trained'] - [to] vs [predictions]
# Iter= 36000, Average Loss= 6.336914, Average Accuracy= 10.60%
# ['structure', ',', 'typically', 'corresponding', 'to', 'a', 'chain'] - [of] vs [the]
# Iter= 37000, Average Loss= 6.144276, Average Accuracy= 10.10%
# ['et', 'al', '.', ',', '1989', ';', 'lang'] - [et] vs [neural]
# Iter= 38000, Average Loss= 5.916501, Average Accuracy= 9.90%
# ['fewer', 'training', 'examples', 'than', 'would', 'be', 'required'] - [without] vs [,]
# Iter= 39000, Average Loss= 5.696152, Average Accuracy= 11.90%
# ['state', 'at', 'time', 't', '+', '1', '.'] - [the] vs [state]
# Iter= 40000, Average Loss= 6.267403, Average Accuracy= 10.70%
# ['neural', 'networks', 'use', 'equation', '10', '.', '5'] - [or] vs [(]
# Iter= 41000, Average Loss= 6.112780, Average Accuracy= 12.70%
# ['.', 'for', 'more', 'information', 'on', 'recurrent', 'neural'] - [networks] vs [networks]
# Iter= 42000, Average Loss= 5.465815, Average Accuracy= 16.70%
# ['that', 'processes', 'sentences', 'of', 'fixed', 'length', '.'] - [a] vs [nepal]
# Iter= 43000, Average Loss= 4.990434, Average Accuracy= 20.40%
# ['possible', 'to', 'use', 'the', 'same', 'transition', 'function'] - [f] vs [of]
# Iter= 44000, Average Loss= 5.095629, Average Accuracy= 19.80%
# ['node', 'for', 'every', 'component', 'that', 'might', 'exist'] - [in] vs [one]
# Iter= 45000, Average Loss= 5.804345, Average Accuracy= 15.00%
# ['system', 'driven', 'by', 'an', 'external', 'signal', 'x'] - [(] vs [3]
# Iter= 46000, Average Loss= 5.500885, Average Accuracy= 16.50%
# ['also', 'be', 'applied', 'in', 'two', 'dimensions', 'across'] - [spatial] vs [to]
# Iter= 47000, Average Loss= 5.311017, Average Accuracy= 20.30%
# ['particularly', 'important', 'when', 'a', 'specific', 'piece', 'of'] - [information] vs [sequence]
# Iter= 48000, Average Loss= 5.673848, Average Accuracy= 17.50%
# ['.', '.', '.', ',', 'x', '(', '2'] - [)] vs [)]
# Iter= 49000, Average Loss= 5.368557, Average Accuracy= 17.70%
# ['in', 'statistical', 'language', 'modeling', ',', 'typically', 'to'] - [predict] vs [the]
# Iter= 50000, Average Loss= 5.517119, Average Accuracy= 18.80%
# ['=', 'f', '(', 's', '(', '2', ')'] - [;] vs [1]
# Iter= 51000, Average Loss= 5.262499, Average Accuracy= 19.60%
# ['of', 'exposition', ',', 'we', 'refer', 'to', 'rnns'] - [as] vs [time]
# Iter= 52000, Average Loss= 2.532689, Average Accuracy= 51.80%
# ['variable', 'length', '.', 'to', 'go', 'from', 'multilayer'] - [networks] vs [time]
# Iter= 53000, Average Loss= 4.852293, Average Accuracy= 28.40%
# ['length', '.', 'we', 'can', 'represent', 'the', 'unfolded'] - [recurrence] vs [as]
# Iter= 54000, Average Loss= 4.756450, Average Accuracy= 26.60%
# ['the', 'past', ',', 'the', 'network', 'typically', 'learns'] - [to] vs [to]
# Iter= 55000, Average Loss= 3.965063, Average Accuracy= 33.00%
# ['results', 'in', 'the', 'sharing', 'of', 'parameters', 'across'] - [a] vs [more]
# Iter= 56000, Average Loss= 4.619680, Average Accuracy= 27.00%
# ['1990', ')', '.', 'the', 'convolution', 'operation', 'allows'] - [a] vs [,]
# Iter= 57000, Average Loss= 3.584371, Average Accuracy= 33.30%
# ['family', 'of', 'neural', 'networks', 'for', 'processing', 'sequential'] - [data] vs [in]
# Iter= 58000, Average Loss= 2.478340, Average Accuracy= 54.70%
# ['other', 'way', 'to', 'draw', 'the', 'rnn', 'is'] - [as] vs [in]
# Iter= 59000, Average Loss= 2.299977, Average Accuracy= 56.20%
# ['of', 'the', 'network', ',', 'we', 'now', 'rewrite'] - [equation] vs [equation]
# Iter= 60000, Average Loss= 3.852659, Average Accuracy= 46.60%
# ['available', 'in', 'this', 'chapter', ',', 'we', 'refer'] - [the] vs [.]
# Iter= 61000, Average Loss= 4.955246, Average Accuracy= 25.10%
# ['length', '.', 'a', 'traditional', 'fully', 'connected', 'feedforward'] - [network] vs [in]
# Iter= 62000, Average Loss= 2.539262, Average Accuracy= 50.30%
# ['f', 'with', 'the', 'same', 'parameters', 'at', 'every'] - [time] vs [time]
# Iter= 63000, Average Loss= 3.089235, Average Accuracy= 45.40%
# ['model', ',', 'such', 'as', 'a', 'biological', 'neural'] - [network] vs [structure]
# Iter= 64000, Average Loss= 2.071311, Average Accuracy= 66.60%
# ['(', 't', ')', '=', 'f', '(', 's'] - [(] vs [(]
# Iter= 65000, Average Loss= 3.532812, Average Accuracy= 45.40%
# ['have', 'connections', 'that', 'go', 'backward', 'in', 'time'] - [,] vs [physical]
# Iter= 66000, Average Loss= 1.653713, Average Accuracy= 62.50%
# ['sequence', '.', 'for', 'example', ',', 'consider', 'the'] - [two] vs [two]
# Iter= 67000, Average Loss= 2.558411, Average Accuracy= 55.50%
# ['1', ')', ')', 'as', 'input', 'and', 'produces'] - [the] vs [the]
# Iter= 68000, Average Loss= 2.723466, Average Accuracy= 51.60%
# ['storing', 'all', 'the', 'information', 'in', 'the', 'input'] - [sequence] vs [sequence]
# Iter= 69000, Average Loss= 1.503951, Average Accuracy= 65.70%
# ['f', '(', 's', '(', '1', ')', ';'] - [theta] vs [theta]
# Iter= 70000, Average Loss= 3.259430, Average Accuracy= 47.50%
# [')', 'with', 'the', 'time', 'step', 'index', 't'] - [ranging] vs [ranging]
# Iter= 71000, Average Loss= 3.104175, Average Accuracy= 53.80%
# ['models', 'of', 'the1980s', ':', 'sharing', 'parameters', 'across'] - [different] vs [a]
# Iter= 72000, Average Loss= 2.215211, Average Accuracy= 53.90%
# ['x', '(', 't', ')', ',', 'x', '('] - [t] vs [t]
# Iter= 73000, Average Loss= 2.136604, Average Accuracy= 58.80%
# ['lossy', ',', 'since', 'it', 'maps', 'an', 'arbitrary'] - [length] vs [length]
# Iter= 74000, Average Loss= 1.788211, Average Accuracy= 64.40%
# ['10', '.', '1', ')', 'where', 's', '('] - [t] vs [t]
# Iter= 75000, Average Loss= 1.209888, Average Accuracy= 73.70%
# ['of', 'parameter', 'sharing', 'manifests', 'in', 'the', 'application'] - [of] vs [of]
# Iter= 76000, Average Loss= 0.801923, Average Accuracy= 82.50%
# ['recurrent', 'neural', 'network', 'is', 'a', 'neural', 'network'] - [that] vs [be]
# Iter= 77000, Average Loss= 1.774137, Average Accuracy= 64.80%
# ['time', '.', 'each', 'variable', 'for', 'each', 'time'] - [step] vs [step]
# Iter= 78000, Average Loss= 1.296074, Average Accuracy= 76.20%
# ['-', '1', ')', ',', 'x', '(', 't'] - [)] vs [-]
# Iter= 79000, Average Loss= 1.219452, Average Accuracy= 75.50%
# ['outputs', 'and', 'loss', '.', 'please', 'refer', 'to'] - [section] vs [section]
# Iter= 80000, Average Loss= 1.350261, Average Accuracy= 73.00%
# ['by', 'comparison', ',', 'a', 'recurrent', 'neural', 'network'] - [shares] vs [shares]
# Iter= 81000, Average Loss= 0.981551, Average Accuracy= 79.60%
# [',', 'rather', 'than', 'needing', 'to', 'learn', 'a'] - [separate] vs [separate]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-0a1119ec3e9f> in <module>()
#      20         symbols_out_onehot = np.reshape(symbols_out_onehot,[1,-1])
#      21
# ---> 22         _, acc, loss, onehot_pred = session.run([optimizer, accuracy, cost, pred],                                                 feed_dict={x: symbols_in_keys, y: symbols_out_onehot})
#      23         loss_total += loss
#      24         acc_total += acc
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ## 6. Excercice
# * Run with 5-7 input words instead of 3.
# * increase number of training iterations, since convergance will take much longer (training as well!).

# %% [markdown]
# ## 7. Further reading

# %% [markdown]
# [Illustrated Guide to Recurrent Neural Networks](https://towardsdatascience.com/illustrated-guide-to-recurrent-neural-networks-79e5eb8049c9)
#
# [Illustrated Guide to LSTM’s and GRU’s: A step by step explanation](https://towardsdatascience.com/illustrated-guide-to-lstms-and-gru-s-a-step-by-step-explanation-44e9eb85bf21)
